# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# 加载数据
file = r'/Users/zhaoxu/Library/CloudStorage/OneDrive-Personal/Scientific Research/Code/Jupyter_YPI/heds/TestData/Helios/Sesame_2eV.exo'
data = xr.open_dataset(file)

# %%
Time = data['time_whole'].values
Radius = data['zone_boundaries'].values
Density = data['mass_density'].values

# %%
data['time_whole'].values
# Out:
# (502,)

# %%
data['mass_density']
# Out:
# <xarray.DataArray 'mass_density' (num_times: 502, num_zones: 100)>
# array([[1.100000e+00, 1.100000e+00, 1.100000e+00, ..., 1.100000e+00,
#         1.100000e+00, 1.100000e+00],
#        [1.100000e+00, 1.100000e+00, 1.100000e+00, ..., 1.100000e+00,
#         1.100615e+00, 1.098069e+00],
#        [1.100000e+00, 1.100000e+00, 1.100000e+00, ..., 1.100000e+00,
#         1.110144e+00, 1.070162e+00],
#        ...,
#        [4.460361e-01, 2.796519e-01, 3.669994e-01, ..., 4.696618e-03,
#         2.132349e-03, 6.218719e-04],
#        [4.460024e-01, 2.786545e-01, 3.654281e-01, ..., 4.685130e-03,
#         2.126148e-03, 6.206679e-04],
#        [4.459893e-01, 2.782877e-01, 3.648497e-01, ..., 4.680879e-03,
#         2.123857e-03, 6.202222e-04]])
# Dimensions without coordinates: num_times, num_zones
# Attributes:
#     info:     Mass density [g per cm3]
#     units:    g per cm3

# %%
data['mass_density'].values
# Out:
# array([[1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10000000e+00, 1.10000000e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10061480e+00, 1.09806853e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.11014392e+00, 1.07016180e+00],
#        ...,
#        [4.46036130e-01, 2.79651858e-01, 3.66999399e-01, ...,
#         4.69661756e-03, 2.13234872e-03, 6.21871926e-04],
#        [4.46002382e-01, 2.78654548e-01, 3.65428088e-01, ...,
#         4.68513050e-03, 2.12614787e-03, 6.20667879e-04],
#        [4.45989328e-01, 2.78287717e-01, 3.64849736e-01, ...,
#         4.68087864e-03, 2.12385662e-03, 6.20222202e-04]])

# %%
data['zone_boundaries']
# Out:
# <xarray.DataArray 'zone_boundaries' (num_times: 502, num_nodes: 101)>
# array([[ 0.000000e+00,  4.000000e-05,  8.000000e-05, ...,  3.920000e-03,
#          3.960000e-03,  4.000000e-03],
#        [ 0.000000e+00,  4.000000e-05,  8.000000e-05, ...,  3.920000e-03,
#          3.959978e-03,  4.000048e-03],
#        [ 0.000000e+00,  4.000000e-05,  8.000000e-05, ...,  3.920000e-03,
#          3.959635e-03,  4.000750e-03],
#        ...,
#        [-2.045294e-03, -1.946647e-03, -1.789308e-03, ...,  3.283252e-02,
#          5.346704e-02,  1.242212e-01],
#        [-2.058999e-03, -1.960344e-03, -1.802443e-03, ...,  3.294039e-02,
#          5.363509e-02,  1.245265e-01],
#        [-2.064086e-03, -1.965429e-03, -1.807319e-03, ...,  3.298046e-02,
#          5.369749e-02,  1.246398e-01]])
# Dimensions without coordinates: num_times, num_nodes
# Attributes:
#     info:     Zone boundary [cm]
#     units:    cm

# %%
data['zone_boundaries'].values
# Out:
# array([[ 0.00000000e+00,  4.00000000e-05,  8.00000009e-05, ...,
#          3.92000000e-03,  3.96000000e-03,  4.00000000e-03],
#        [ 0.00000000e+00,  4.00000000e-05,  8.00000009e-05, ...,
#          3.92000000e-03,  3.95997766e-03,  4.00004801e-03],
#        [ 0.00000000e+00,  4.00000000e-05,  8.00000009e-05, ...,
#          3.92000000e-03,  3.95963450e-03,  4.00074978e-03],
#        ...,
#        [-2.04529363e-03, -1.94664691e-03, -1.78930842e-03, ...,
#          3.28325185e-02,  5.34670426e-02,  1.24221161e-01],
#        [-2.05899862e-03, -1.96034444e-03, -1.80244283e-03, ...,
#          3.29403852e-02,  5.36350893e-02,  1.24526465e-01],
#        [-2.06408591e-03, -1.96542884e-03, -1.80731909e-03, ...,
#          3.29804577e-02,  5.36974875e-02,  1.24639804e-01]])

# %%
Density
# Out:
# array([[1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10000000e+00, 1.10000000e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10061480e+00, 1.09806853e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.11014392e+00, 1.07016180e+00],
#        ...,
#        [4.46036130e-01, 2.79651858e-01, 3.66999399e-01, ...,
#         4.69661756e-03, 2.13234872e-03, 6.21871926e-04],
#        [4.46002382e-01, 2.78654548e-01, 3.65428088e-01, ...,
#         4.68513050e-03, 2.12614787e-03, 6.20667879e-04],
#        [4.45989328e-01, 2.78287717e-01, 3.64849736e-01, ...,
#         4.68087864e-03, 2.12385662e-03, 6.20222202e-04]])

# %%
Z
# Out:
# array([[1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10000000e+00, 1.10000000e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.10061480e+00, 1.09806853e+00],
#        [1.10000000e+00, 1.10000000e+00, 1.10000000e+00, ...,
#         1.10000000e+00, 1.11014392e+00, 1.07016180e+00],
#        ...,
#        [4.46067976e-01, 2.80662337e-01, 3.68589910e-01, ...,
#         4.70814943e-03, 2.13858955e-03, 6.23080653e-04],
#        [4.46036130e-01, 2.79651858e-01, 3.66999399e-01, ...,
#         4.69661756e-03, 2.13234872e-03, 6.21871926e-04],
#        [4.46002382e-01, 2.78654548e-01, 3.65428088e-01, ...,
#         4.68513050e-03, 2.12614787e-03, 6.20667879e-04]])

# %%
time = data['time_whole'].values  # 转换为 numpy 数组
radius = data['zone_boundaries'].values  # 转换为 numpy 数组
density = data['mass_density'].values  # 转换为 numpy 数组

# 修剪 radius 的形状以匹配 density 的形状
radius_adjusted = radius[:, :-1]  # 修剪最后一列

# 绘制图像
plt.figure(figsize=(10, 6))
plt.pcolormesh(time, radius_adjusted.T, density.T, shading='auto')  # 转置 radius 和 density 以匹配时间
plt.colorbar(label='Mass Density')
plt.xlabel('Time')
plt.ylabel('Radius (Zone Boundaries)')
plt.title('Mass Density over Time and Varying Radius')
plt.ylim(-10e-4, 60e-4)
plt.show(block=True)
# Out:
# /var/folders/8x/8b_22rcx3qvdx_26x022tzbw0000gn/T/ipykernel_32540/1453903699.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(time, radius_adjusted.T, density.T, shading='auto')  # 转置 radius 和 density 以匹配时间

# %%
# Out:
# (503,)

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))

# 遍历每个 zone（每个半径位置），绘制 radius 随时间的变化
for i in range(radius.shape[1]):  # 对每个半径位置（zone）进行遍历
    plt.plot(time, radius[:, i], c = 'k')  # 仅显示部分标签，避免过多标签重叠

plt.xlabel("Time (ns)")
plt.ylabel("Radius (micron)")
plt.title("Radius Evolution Over Time for Each Zone")
# plt.legend(loc='upper left', fontsize='small', ncol=2)  # 显示部分标签
plt.xlim(0,5e-9)
plt.ylim(-10e-4, 60e-4)
plt.show(block=True)
